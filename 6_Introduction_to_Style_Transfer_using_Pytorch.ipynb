# %% [markdown]
# <a href="https://colab.research.google.com/github/mlvlab/COSE474/blob/master/6_Introduction_to_Style_Transfer_using_Pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Introduction to Style Transfer in PyTorch
#
#
#
#
# ### Reference
# * [CycleGAN github code](https://github.com/rahulbhalley/cyclegan-qp)
# * [CycleGAN paper](https://arxiv.org/pdf/1703.10593.pdf)
# * [Blog: Style Transfer with GANs on HD images](https://towardsdatascience.com/style-transfer-with-gans-on-hd-images-88e8efcf3716)

# %% [markdown]
# ### GOALS
# 1. we will first clone git repository cyclegan-qp.
# 2. Then, we will mount the Google Drive to Colab in order to download files into Google Drive via Colab.
# 3. Download pretrained weight of CycleGAN to My Drive.
# 4. we will test the style transfer.

# %%
# !git clone https://github.com/dasolhwang/cyclegan-qp
# Out:
# Cloning into 'cyclegan-qp'...
# remote: Enumerating objects: 32, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 165 (delta 15), reused 14 (delta 5), pack-reused 133
# Receiving objects: 100% (165/165), 5.51 MiB | 23.52 MiB/s, done.
# Resolving deltas: 100% (79/79), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# ### cycleGAN pretrained weight download link ( Save to My Drive )
# - https://drive.google.com/drive/folders/1IJ0OswLFD_-P2wgDg6RJhf29AQxYUc0_?usp=sharing
# - 내 드라이브에 추가하기
#
#
# - Style types
#   - vg : Vincent Van Gogh
#   - uk : Ukiyo-e
#   - mo : Claude Monet
#   - ce : Paul Cézanne
#
#
# ex)
#
#     drive/My\ Drive/vg/G_15000.pth
#     drive/My\ Drive/vg/F_15000.pth
#
#     drive/My\ Drive/uk/G_12000.pth
#     drive/My\ Drive/uk/F_12000.pth

# %%
# default vg style
# !cp -a drive/My\ Drive/vg cyclegan-qp/vg

# !cp -a drive/My\ Drive/uk cyclegan-qp/uk

# !cp -a drive/My\ Drive/mo cyclegan-qp/mo

# !cp -a drive/My\ Drive/ce cyclegan-qp/ce

# %%
# !python cyclegan-qp/main.py 'hills.jpg' 'mo'
# Out:
# Inference: Loaded the checkpoints from 15000th iteration.
# Stylization
# Reconstruction
# Saved samples/mo/rec/rec_hills_mo_15k.jpg
# Saved samples/mo/sty/sty_hills_mo_15k.jpg

# %%
  from PIL import Image
import matplotlib.pyplot as plt

reco = Image.open('./samples/mo/rec/rec_hills_mo_15k.jpg')
sty = Image.open('./samples/mo/sty/sty_hills_mo_15k.jpg')

plt.imshow(reco); plt.show()
plt.imshow(sty); plt.show()

# %%
# !python cyclegan-qp/main.py 'sun_flower.jpg' 'vg'
# Out:
# Inference: Loaded the checkpoints from 15000th iteration.
# Stylization
# Reconstruction
# Saved samples/vg/rec/rec_sun_flower_vg_15k.jpg
# Saved samples/vg/sty/sty_sun_flower_vg_15k.jpg

# %%
from PIL import Image
import matplotlib.pyplot as plt

reco = Image.open('./samples/vg/rec/rec_sun_flower_vg_15k.jpg')
sty = Image.open('./samples/vg/sty/sty_sun_flower_vg_15k.jpg')

plt.imshow(reco); plt.show()
plt.imshow(sty); plt.show()

# %%
# !python cyclegan-qp/main.py 'bus.jpg' 'ce'
# Out:
# Inference: Loaded the checkpoints from 15000th iteration.
# Stylization
# Reconstruction
# Saved samples/ce/rec/rec_bus_ce_15k.jpg
# Saved samples/ce/sty/sty_bus_ce_15k.jpg

# %%
from PIL import Image
import matplotlib.pyplot as plt

reco = Image.open('./samples/ce/rec/rec_bus_ce_15k.jpg')
sty = Image.open('./samples/ce/sty/sty_bus_ce_15k.jpg')

plt.imshow(reco); plt.show()
plt.imshow(sty); plt.show()

# %%
# !python cyclegan-qp/main.py 'flower.jpg' 'uk'
# Out:
# Inference: Loaded the checkpoints from 12000th iteration.
# Stylization
# Reconstruction
# Saved samples/uk/rec/rec_flower_uk_12k.jpg
# Saved samples/uk/sty/sty_flower_uk_12k.jpg

# %%
from PIL import Image
import matplotlib.pyplot as plt

reco = Image.open('./samples/uk/rec/rec_flower_uk_12k.jpg')
sty = Image.open('./samples/uk/sty/sty_flower_uk_12k.jpg')

plt.imshow(reco); plt.show()
plt.imshow(sty); plt.show()

# %%
# local image upload
from google.colab import files
image = files.upload()
# Out:
#      <input type="file" id="files-b2fbdb5e-5206-44db-93e0-95b319c27961" name="files[]" multiple disabled />
#      <output id="result-b2fbdb5e-5206-44db-93e0-95b319c27961">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving apple.jpg to apple.jpg

# %%
#!mv 'apple.jpg' cyclegan-qp/images/apple.jpg
# !mv {file-name} cyclegan-qp/images/{file-name}

# %%
#!python cyclegan-qp/main.py 'apple.jpg' 'uk'
# !python cyclegan-qp/main.py 'file-name' 'style type'
# Out:
# Inference: Loaded the checkpoints from 12000th iteration.
# Stylization
# Reconstruction
# Saved samples/uk/rec/rec_apple_uk_12k.jpg
# Saved samples/uk/sty/sty_apple_uk_12k.jpg

# %%
from PIL import Image
import matplotlib.pyplot as plt

reco = Image.open('./samples/uk/rec/rec_apple_uk_12k.jpg')
sty = Image.open('./samples/uk/sty/sty_apple_uk_12k.jpg')

plt.imshow(reco); plt.show()
plt.imshow(sty); plt.show()
